# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def ratio_func(t, alpha, n):
    return ((t**(alpha*t))/(1+2*alpha*t))**n

def ratio_by_n(n):
    return ratio_func(5, 0.1, n)

# %%
plt.plot(ratio_by_n(n_hidden))

# %%
ratio_func(5, 0.06, 10)
# Out:
# 1.1368683772161599

# %%
np.e**2
# Out:
# 7.3890560989306495

# %%
n_hidden = np.array(range(1, 16))
for alpha in np.arange(0,1,0.1):
    plt.plot(n_hidden, ratio_func(8,alpha,n_hidden), label=f"alpha:{alpha:.3f}")
plt.yscale("log")
plt.legend()
